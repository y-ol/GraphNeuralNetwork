# %%
# %reload_ext autoreload
# %autoreload 2
import eval

# %%
eval.eval_table()
# Out:
# (10, 12)
#   convoType regularization  molhivAvg  ...  molfreesolvStd  mollipoAvg  mollipoStd
# 0       gcn           None   0.508303  ...        1.705412    0.689785    0.018323
# 1       gcn        DropOut   0.466110  ...        0.770158    1.111724    0.010417
# 2       gcn   NodeSampling   0.539958  ...        0.586268    1.060462    0.017981
# 3       gcn       DropEdge   0.477641  ...        2.582159    0.820521    0.050423
# 4       gcn            GDC   0.537316  ...        1.193070    1.017545    0.032613
# 5       gin           None   0.700353  ...        0.703757    0.745814    0.049410
# 6       gin        DropOut   0.482186  ...        1.154138    1.098258    0.019997
# 7       gin   NodeSampling   0.549163  ...        1.797512    0.937417    0.041674
# 8       gin       DropEdge   0.459072  ...        0.170044    0.784164    0.052014
# 9       gin            GDC   0.511594  ...        3.499242    1.055488    0.044651
#
# [10 rows x 12 columns]

# %%
eval.eval_plot() # Kann mit PGFplots in Latex als line-chart geplottet werden!
# Out:
# (6, 12)
#   convoType numLayers    noneAvg  ...  dropedgeStd     gdcAvg    gdcStd
# 0       gcn         1  10.289427  ...     0.699232  13.620146  1.237801
# 1       gcn         2  10.075557  ...     1.397911  13.286070  1.193070
# 2       gcn         3  10.006081  ...     2.582159  17.310296  1.436351
# 3       gcn         4   9.405988  ...     0.263610  13.243672  0.239230
# 4       gcn         5   9.850549  ...     1.413400  15.726051  1.267048
# 5       gcn         6   9.397256  ...     2.893047  16.777755  0.876588
#
# [6 rows x 12 columns]

# %%
eval.add_metric_from_history("ogbg-molpcba", "val_precision", mode="max")
# Out:
# Fixing 1/2810 (mode='max')
# Fixing 2/2810 (mode='max')
# Fixing 3/2810 (mode='max')
# Fixing 4/2810 (mode='max')
# Fixing 5/2810 (mode='max')
# Fixing 6/2810 (mode='max')
# Fixing 7/2810 (mode='max')
# Fixing 8/2810 (mode='max')
# Fixing 9/2810 (mode='max')
# Fixing 10/2810 (mode='max')
# Fixing 11/2810 (mode='max')
# Fixing 12/2810 (mode='max')
# Fixing 13/2810 (mode='max')
# Fixing 14/2810 (mode='max')
# Fixing 15/2810 (mode='max')
# Fixing 16/2810 (mode='max')
# Fixing 17/2810 (mode='max')
# Fixing 18/2810 (mode='max')
# Fixing 19/2810 (mode='max')
# Fixing 20/2810 (mode='max')
# Fixing 21/2810 (mode='max')
# Fixing 22/2810 (mode='max')
# Fixing 23/2810 (mode='max')
# Fixing 24/2810 (mode='max')
# Fixing 25/2810 (mode='max')
# Fixing 26/2810 (mode='max')
# Fixing 27/2810 (mode='max')
# Fixing 28/2810 (mode='max')
# Fixing 29/2810 (mode='max')
# Fixing 30/2810 (mode='max')
# Fixing 31/2810 (mode='max')
# Fixing 32/2810 (mode='max')
# Fixing 33/2810 (mode='max')
# ...
